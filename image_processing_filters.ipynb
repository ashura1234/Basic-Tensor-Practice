# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %%
#reading in an image
image = mpimg.imread('test_images/1.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(image_gray, cmap='gray')

# %% [markdown]
# ## adjust brightness

# %%
image_gray.max()
# Out:
# 255

# %% [markdown]
# ## adjust contrast

# %% [markdown]
# ## filters

# %%
kernel = np.ones((15,15),np.float32)/225

# %%
dst = cv2.filter2D(image_gray,-1,kernel)

# %%
plt.imshow(dst, cmap='gray')

# %%
plt.imwrite(dst,)

# %%
image.shape (3,658,990)
# Out:
# (658, 990, 3)

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)

plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# gaussian kernel
blur = cv2.GaussianBlur(image_gray,(25,25),0)

# %%
plt.subplot(211),plt.imshow(image_gray, cmap='gray'),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(212),plt.imshow(blur, cmap='gray'),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
# noise removal filters
# these are not convolutional
median = cv2.medianBlur(img,5)
blur = cv2.bilateralFilter(img,9,75,75)
